# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %ls -1 gcp/ | grep csv
# Out:
# test-generated.csv
# test-measurement.csv

# %%
df = pd.read_csv('gcp/test-measurement.csv')
pd.set_option('display.max_columns', 100)
cols = ['max_var_shift', 'max_kl_shift', 'seas_pacf', 'seasonal_strength']
df = df[cols]
df.dropna(inplace=True)

# %% [markdown]
# ` "max_var_shift", "max_kl_shift", "seas_pacf", "seasonal_strength"`
# ```
# -> Feature to check
#
# # Entropy - 0.5  - 0.9 entropy
#
# Strong features (constant)
# # max_var_shift - 77
# # max_kl_shift - 73
# # seas_pacf - 0.01
# # seasonal_strength - 190
# ```

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.head(10)
# Out:
#    max_var_shift  max_kl_shift  seas_pacf  seasonal_strength
# 0       0.335499      0.294140   0.454827           0.915742
# 1       1.432262      2.997169   0.264887           0.577860
# 2       1.045010      1.564328   0.292829           0.812015
# 3       1.746730      3.135674   0.268392           0.791560
# 4       0.655518      0.103129   0.724873           0.919626
# 5       0.802530      0.050482   0.590869           0.908940
# 6       0.856800      6.042308   0.220068           0.567245
# 7       0.408099      0.212030   0.623239           0.893690
# 8       1.579110      1.061029   0.267152           0.737452
# 9       0.182940      0.559341   0.444496           0.919400

# %%
df.hist(figsize=(10, 9), sharey=True);

# %%
df.mean()
# Out:
# max_var_shift        0.859709
# max_kl_shift         9.844323
# seas_pacf            0.291187
# seasonal_strength    0.789379
# dtype: float64

# %%
df.loc[:1000,'entropy'].hist(figsize=(6, 3`

# %%
df.loc[1000:,'entropy'].hist(figsize=(6, 4));
