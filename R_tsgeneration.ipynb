# %%
library('tsgeneration')
# Out:
# Warning message in as.POSIXlt.POSIXct(Sys.time()):
# “unknown timezone 'zone/tz/2018i.1.0/zoneinfo/Asia/Jerusalem'”

# %%
x <- generate_ts_with_target(n = 1, ts.length = 60, freq = 1, seasonal = 0,
                             features = c('entropy', 'stl_features'),
                             selected.features = c('entropy', 'trend'),
                             target = c(0.6, 0.9))
# Out:
# Error in startParallel(parallel): packages 'parallel' and 'doParallel' required for parallelization!
# Traceback:
#
# 1. generate_ts_with_target(n = 1, ts.length = 60, freq = 1, seasonal = 0,
#  .     features = c("entropy", "stl_features"), selected.features = c("entropy",
#  .         "trend"), target = c(0.6, 0.9))
# 2. ga_ts(type = "real-valued", fitness = tsgeneration::fitness_ts,
#  .     features = features, seasonal = seasonal, ts.length, freq,
#  .     target, 3, selected.features, n = ts.length, min = ga_min,
#  .     max = ga_max, parallel = parallel, popSize = 30, maxiter = 100,
#  .     pmutation = 0.3, pcrossover = 0.8, maxFitness = -0.05, run = 30,
#  .     keepBest = TRUE, monitor = GA::gaMonitor)
# 3. startParallel(parallel)
# 4. stop("packages 'parallel' and 'doParallel' required for parallelization!")

# %%
x <- generate_ts_with_target(n = 1, ts.length = 60, freq = 1, seasonal = 0,
                             features = c('entropy', 'stl_features'),
                             selected.features = c('entropy', 'trend'),
                             target = c(0.6, 0.9))

# %%
autoplot(x)
